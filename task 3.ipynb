# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv("twitter_training.csv")

# %%
train.head
# Out:
# <bound method NDFrame.head of        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# ...

# %%
train.shape
# Out:
# (74681, 4)

# %%
train.info
# Out:
# <bound method DataFrame.info of        2401  Borderlands  Positive  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74676  9200       Nvidia  Positive
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 0      I am coming to the borders and I will kill you...
# 1      im getting on borderlands and i will kill you ...
# 2      im coming on borderlands and i will murder you...
# 3      im getting on borderlands 2 and i will murder ...
# 4      im getting into borderlands and i can murder y...
# ...                                                  ...
# 74676  Just realized that the Windows partition of my...
# ...

# %%
train.describe(include=object)
# Out:
#        Borderlands  Positive  \
# count        74681     74681
# unique          32         4
# top      Microsoft  Negative
# freq          2400     22542
#
#        im getting on borderlands and i will murder you all ,
# count                                               73995
# unique                                              69490
# top     At the same time, despite the fact that there ...
# freq                                                  172

# %%
train['Positive'].unique()
# Out:
# array(['Positive', 'Neutral', 'Negative', 'Irrelevant'], dtype=object)

# %%
train.isnull().sum()
# Out:
# 2401                                                       0
# Borderlands                                                0
# Positive                                                   0
# im getting on borderlands and i will murder you all ,    686
# dtype: int64

# %%
train.dropna(inplace=True)

# %%
train.isnull().sum()
# Out:
# 2401                                                     0
# Borderlands                                              0
# Positive                                                 0
# im getting on borderlands and i will murder you all ,    0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# np.int64(2340)

# %%
train.drop_duplicates(inplace=True)

# %%
train.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(8,10))
train['Borderlands'].value_counts().plot(kind='barh',color='g')
plt.xlabel("Count")
plt.show()

# %%
sns.countplot(x = 'Positive',data=train,palette='viridis')
plt.show()
# Out:
# C:\Users\KARAN PREET SINGH\AppData\Local\Temp\ipykernel_9252\2043918692.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'Positive',data=train,palette='viridis')

# %%
plt.figure(figsize=(20,12))
sns.countplot(x='Borderlands',data=train,palette='viridis',hue='Positive')
plt.xticks(rotation=90)
plt.show()
